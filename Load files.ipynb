# %%
import pandas as pd

# %%
result = pd.read_csv('results.csv')
# Out:
#                                               titles  \
# 0                             Software Engineer\nnew
# 1  Software Engineer/ Programmer - Training Provi...
# 2   Business Development Manager (IT/ Software)\nnew
# 3  Maintenance Engineer (SCADA & Substation Autom...
# 4                           Automation Engineer\nnew
#
#                              companies  \
# 0              A2000 Solutions Pte Ltd
# 1                      Anradus Pte Ltd
# 2                      Anradus Pte Ltd
# 3                      Anradus Pte Ltd
# 4  ATS Automation Tooling Systems Inc.
#
#                                                links  date_listed
# 0  www.Indeed.co.uk//rc/clk?jk=7d3a477772f62a2e&f...  Just posted
# 1  www.Indeed.co.uk//company/Anradus-Pte-Ltd/jobs...  Just posted
# 2  www.Indeed.co.uk//company/Anradus-Pte-Ltd/jobs...  Just posted
# 3  www.Indeed.co.uk//company/Anradus-Pte-Ltd/jobs...  Just posted
# 4  www.Indeed.co.uk//rc/clk?jk=90469b0a39801802&f...  Just posted

# %%
result
# Out:
#                                                  titles  \
# 0                                Software Engineer\nnew
# 1     Software Engineer/ Programmer - Training Provi...
# 2      Business Development Manager (IT/ Software)\nnew
# 3     Maintenance Engineer (SCADA & Substation Autom...
# 4                              Automation Engineer\nnew
# ...                                                 ...
# 1120  .NET Core Senior Full-stack Developer (Permanent)
# 1121         Android Developer - Global eCommerce Brand
# 1122       C#.NET Software Developer - Technology Brand
# 1123                               Full Stack Developer
# 1124                     Computer Vision & ML Developer
#
#                                 companies  \
# 0                 A2000 Solutions Pte Ltd
# 1                         Anradus Pte Ltd
# 2                         Anradus Pte Ltd
# 3                         Anradus Pte Ltd
# 4     ATS Automation Tooling Systems Inc.
# ...
